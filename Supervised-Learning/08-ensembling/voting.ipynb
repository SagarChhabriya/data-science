# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SagarChhabriya/data-science/refs/heads/main/datasets/02-Multiple-Regression/car_depriciation.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Initial_Price  KM_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59      27000    Petrol
# 1        sx4  2013           4.75           9.54      43000    Diesel
# 2       ciaz  2017           7.25           9.85       6900    Petrol
# 3    wagon r  2011           2.85           4.15       5200    Petrol
# 4      swift  2014           4.60           6.87      42450    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60      33988    Diesel
# 297     brio  2015           4.00           5.90      60000    Petrol
# 298     city  2009           3.35          11.00      87934    Petrol
# 299     city  2017          11.50          12.50       9000    Diesel
# 300     brio  2016           5.30           5.90       5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
columns = ['car_name', 'year',' selling_price', 'initial_price' , 'km_driven', 'fuel_type', 'seller_type', 'transmission', 'owner']
df.columns = columns
df
# Out:
#     car_name  year   selling_price  initial_price  km_driven fuel_type  \
# 0       ritz  2014            3.35           5.59      27000    Petrol
# 1        sx4  2013            4.75           9.54      43000    Diesel
# 2       ciaz  2017            7.25           9.85       6900    Petrol
# 3    wagon r  2011            2.85           4.15       5200    Petrol
# 4      swift  2014            4.60           6.87      42450    Diesel
# ..       ...   ...             ...            ...        ...       ...
# 296     city  2016            9.50          11.60      33988    Diesel
# 297     brio  2015            4.00           5.90      60000    Petrol
# 298     city  2009            3.35          11.00      87934    Petrol
# 299     city  2017           11.50          12.50       9000    Diesel
# 300     brio  2016            5.30           5.90       5464    Petrol
#
#     seller_type transmission  owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.drop(columns=['car_name'], inplace=True)

# %%
df
# Out:
#      year   selling_price  initial_price  km_driven fuel_type seller_type  \
# 0    2014            3.35           5.59      27000    Petrol      Dealer
# 1    2013            4.75           9.54      43000    Diesel      Dealer
# 2    2017            7.25           9.85       6900    Petrol      Dealer
# 3    2011            2.85           4.15       5200    Petrol      Dealer
# 4    2014            4.60           6.87      42450    Diesel      Dealer
# ..    ...             ...            ...        ...       ...         ...
# 296  2016            9.50          11.60      33988    Diesel      Dealer
# 297  2015            4.00           5.90      60000    Petrol      Dealer
# 298  2009            3.35          11.00      87934    Petrol      Dealer
# 299  2017           11.50          12.50       9000    Diesel      Dealer
# 300  2016            5.30           5.90       5464    Petrol      Dealer
#
#     transmission  owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2005     4
# 2006     4
# 2007     2
# 2003     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# year              0
#  selling_price    0
# initial_price     0
# km_driven         0
# fuel_type         0
# seller_type       0
# transmission      0
# owner             0
# dtype: int64

# %%
# fuel_type seller_type transimission 
df
# Out:
#      year   selling_price  initial_price  km_driven fuel_type seller_type  \
# 0    2014            3.35           5.59      27000    Petrol      Dealer
# 1    2013            4.75           9.54      43000    Diesel      Dealer
# 2    2017            7.25           9.85       6900    Petrol      Dealer
# 3    2011            2.85           4.15       5200    Petrol      Dealer
# 4    2014            4.60           6.87      42450    Diesel      Dealer
# ..    ...             ...            ...        ...       ...         ...
# 296  2016            9.50          11.60      33988    Diesel      Dealer
# 297  2015            4.00           5.90      60000    Petrol      Dealer
# 298  2009            3.35          11.00      87934    Petrol      Dealer
# 299  2017           11.50          12.50       9000    Diesel      Dealer
# 300  2016            5.30           5.90       5464    Petrol      Dealer
#
#     transmission  owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df = pd.get_dummies(df, dtype='int', drop_first=True)
df
# Out:
#      year   selling_price  initial_price  km_driven  owner  fuel_type_Diesel  \
# 0    2014            3.35           5.59      27000      0                 0
# 1    2013            4.75           9.54      43000      0                 1
# 2    2017            7.25           9.85       6900      0                 0
# 3    2011            2.85           4.15       5200      0                 0
# 4    2014            4.60           6.87      42450      0                 1
# ..    ...             ...            ...        ...    ...               ...
# 296  2016            9.50          11.60      33988      0                 1
# 297  2015            4.00           5.90      60000      0                 0
# 298  2009            3.35          11.00      87934      0                 0
# 299  2017           11.50          12.50       9000      0                 1
# 300  2016            5.30           5.90       5464      0                 0
#
# ...
